# %%
import pandas as pd
import numpy as np
import joblib
import matplotlib.pyplot as plt
import shap

# %pip install ipywidgets jupyter

model_rf = joblib.load('disk_model.pkl')
X_test = pd.read_csv('X_test_shap.csv')

#explainer - shap razlaga
#za drevesen modele random forest, XGboost, uporabimo TreeExplainer
explainer = shap.TreeExplainer(model_rf)

shap_values = explainer.shap_values(X_test)

#lahko vrnemo matriko ali 3D matriko ali lista
if isinstance(shap_values, list):
    shap_values_failures = shap_values[1]
elif len(shap_values.shape) == 3:
    shap_values_failure = shap_values[:, :, 1]
else:
    shap_values_failure = shap_values

shap.initjs()
# Out:
# Requirement already satisfied: ipywidgets in c:\projects\diskfailureprediction\.venv\lib\site-packages (8.1.8)
# Requirement already satisfied: jupyter in c:\projects\diskfailureprediction\.venv\lib\site-packages (1.1.1)
# Requirement already satisfied: comm>=0.1.3 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from ipywidgets) (8.39.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from ipywidgets) (5.15.1)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: notebook in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyter) (7.5.7)
# Requirement already satisfied: jupyter-console in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyter) (7.17.1)
# Requirement already satisfied: ipykernel in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyter) (7.3.0)
# Requirement already satisfied: jupyterlab in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyter) (4.5.9)
# Requirement already satisfied: colorama in c:\projects\diskfailureprediction\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in c:\projects\diskfailureprediction\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.3.1)
# Requirement already satisfied: exceptiongroup in c:\projects\diskfailureprediction\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.3.1)
# Requirement already satisfied: jedi>=0.16 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.20.0)
# Requirement already satisfied: matplotlib-inline in c:\projects\diskfailureprediction\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.20.0)
# Requirement already satisfied: stack_data in c:\projects\diskfailureprediction\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.15.0)
# Requirement already satisfied: wcwidth in c:\projects\diskfailureprediction\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.8.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.7)
# Requirement already satisfied: debugpy>=1.6.5 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from ipykernel->jupyter) (1.8.21)
# Requirement already satisfied: jupyter-client>=8.9.0 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from ipykernel->jupyter) (8.9.1)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from ipykernel->jupyter) (5.9.1)
# Requirement already satisfied: nest-asyncio2>=1.7.0 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from ipykernel->jupyter) (1.7.2)
# Requirement already satisfied: packaging>=22 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from ipykernel->jupyter) (26.2)
# Requirement already satisfied: psutil>=5.7 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from ipykernel->jupyter) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from ipykernel->jupyter) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from ipykernel->jupyter) (6.5.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyter-client>=8.9.0->ipykernel->jupyter) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel->jupyter) (4.10.0)
# Requirement already satisfied: six>=1.5 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.9.0->ipykernel->jupyter) (1.17.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyterlab->jupyter) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyterlab->jupyter) (2.3.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyterlab->jupyter) (2.20.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyterlab->jupyter) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyterlab->jupyter) (80.3.1)
# Requirement already satisfied: tomli>=1.2.2 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyterlab->jupyter) (2.4.1)
# Requirement already satisfied: anyio in c:\projects\diskfailureprediction\.venv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (4.13.0)
# Requirement already satisfied: certifi in c:\projects\diskfailureprediction\.venv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in c:\projects\diskfailureprediction\.venv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: idna in c:\projects\diskfailureprediction\.venv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (3.17)
# Requirement already satisfied: h11>=0.16 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.25.0)
# Requirement already satisfied: pywinpty!=3.0.4,>=2.0.1 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.5)
# Requirement already satisfied: send2trash>=1.8.2 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.9.0)
# Requirement already satisfied: babel>=2.10 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.14.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (4.26.0)
# Requirement already satisfied: requests>=2.31 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.34.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\projects\diskfailureprediction\.venv\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jinja2>=3.0.3->jupyterlab->jupyter) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (0.30.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (4.1.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.3)
# Requirement already satisfied: rfc3339-validator in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: fqdn in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.1.0)
# Requirement already satisfied: uri-template in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from nbconvert->jupyter) (4.15.0)
# Requirement already satisfied: bleach!=5.0.0 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.4.0)
# Requirement already satisfied: defusedxml in c:\projects\diskfailureprediction\.venv\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\projects\diskfailureprediction\.venv\lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from nbconvert->jupyter) (3.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from nbconvert->jupyter) (0.11.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in c:\projects\diskfailureprediction\.venv\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2>=1.1.0 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.21.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter) (2.7.0)
# Requirement already satisfied: lark>=1.2.2 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.0)
# Requirement already satisfied: pycparser in c:\projects\diskfailureprediction\.venv\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.8.4)
# Requirement already satisfied: arrow>=0.15.0 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.4.0)
# Requirement already satisfied: tzdata in c:\projects\diskfailureprediction\.venv\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2026.2)
# Requirement already satisfied: executing>=1.2.0 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\projects\diskfailureprediction\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in c:\projects\diskfailureprediction\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},u=Symbol.for("react.portal"),l=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:u,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=l.T,n=o.p;try{if(l.T=null,o.p=2,e)return e()}finally{l.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return l.H.useFormState(e,t,n)},t.useFormStatus=function(){return l.H.useHostTransitionStatus()},t.version="19.1.1"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function u(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function l(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&n ...

# %% [markdown]
# **VIZUALIZACIJA ODLOČITVE MODELA (GRAFI)**

# %%
#Klasičen bar plot (povprečni absolutni vpliv)
print("\n--- PRIKAZ GLOBALNE POMEMBNOSTI ZNAČILNIC ---")
plt.figure(figsize=(10, 5))
shap.summary_plot(shap_values_failure, X_test, plot_type="bar")

print("\n--- ODLOČANJE MODELA ZA VSE DISKE ---")
#Beeswarm graf (gostota in smer vpliva za vsak disk posebej)
plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values_failure, X_test)


print("\n--- PRIKAZ ODLOČITVE ZA POSAMEZEN DISK ---")

def odlocitvePosaznegaDiska(izbrani_idx):

    # Priprava Explanation objekta, ki ga zahteva funkcija waterfall
    domena_razlage = shap.Explanation(
        values=shap_values_failure[izbrani_idx],
        base_values=explainer.expected_value[1] if isinstance(explainer.expected_value, (list, np.ndarray)) else explainer.expected_value,
        data=X_test.iloc[izbrani_idx],
        feature_names=X_test.columns
    )

    plt.figure(figsize=(10, 6))
    shap.plots.waterfall(domena_razlage)

print("\n--- NAJBOLJ KRITIČEN DISK: ---")
odlocitvePosaznegaDiska(879)
print("\n--- NAJBOLJ OPTIMALEN DISK: ---")
odlocitvePosaznegaDiska(1)
print("\n--- NEKJE UMES: ---")
odlocitvePosaznegaDiska(1588)

print("\n--- PRIKAZ VPLIVA STAROSTI DISKA (SMART 9) ---")

#pri kolikšnem številu ur začne starost drastično dvigovati tveganje
shap.dependence_plot("smart_9_raw", shap_values_failure, X_test)

#shap value for raw 9 je "kazen" glede na koliko doprinese starost k analizi na koncu... pac cuden graf je
# Out:
# --- PRIKAZ GLOBALNE POMEMBNOSTI ZNAČILNIC ---
# --- ODLOČANJE MODELA ZA VSE DISKE ---
# --- PRIKAZ ODLOČITVE ZA POSAMEZEN DISK ---
#
# --- NAJBOLJ KRITIČEN DISK: ---
# --- NAJBOLJ OPTIMALEN DISK: ---
# --- NEKJE UMES: ---
# --- PRIKAZ VPLIVA STAROSTI DISKA (SMART 9) ---
